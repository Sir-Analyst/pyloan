# %%
#package:
import pandas as pd
from loan_amortization import calculate_amortization

# %%
result = calculate_amortization(principal=10000, annual_interest_rate=5, years=2)
print(result["AmortizationTable"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\smahd\OneDrive\Desktop\pyloan\notebooks\loan.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/smahd/OneDrive/Desktop/pyloan/notebooks/loan.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> result = calculate_amortization(principal=10000, annual_interest_rate=5, years=2)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/smahd/OneDrive/Desktop/pyloan/notebooks/loan.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> print(result["AmortizationTable"])
#
# KeyError: 'AmortizationTable'

# %%
# Check if the result is a dictionary
if isinstance(result, dict):
    # Access the 'AmortizationTable' key if it exists
    amortization_table = result.get("AmortizationTable")
    if amortization_table is not None:
        print(amortization_table)
    else:
        print("The 'AmortizationTable' key does not exist in the result.")
else:
    print("The result is not a dictionary.")
# Out:
# The 'AmortizationTable' key does not exist in the result.
